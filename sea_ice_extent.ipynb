# %%
# %matplotlib widget
# %matplotlib tk

"""
Use data from : https://www.polarview.aq/antarctic

and download it as a geoTIFF

"""


import rasterio
import numpy as np
day = '20260215'
day2 = '20260111'
# Define the file path
filepath = f'/Users/iw2g24/PycharmProjects/COOKIES/Data/sea_ice/polarview/27_AMSR2/{day}/{day}.antarctic.tif'
filepath2 = f'/Users/iw2g24/PycharmProjects/COOKIES/Data/sea_ice/polarview/27_AMSR2/{day2}/{day2}.antarctic.tif'

cook_lon, cook_lat = 151.4, -69.1

# Open the raster file in read mode using a context manager
with rasterio.open(filepath) as src:
    # Read the first band (GeoTIFFs can have multiple bands)
    # The data is returned as a NumPy array
    image_array = src.read(1)

    # Access metadata
    print("Image shape:", image_array.shape)
    print("Coordinate Reference System (CRS):", src.crs)
    print("NoData value:", src.nodata)
    print("GeoTransform (affine transform):", src.transform)
    print("Grid resolution (x, y):", src.res)
# Out:
# Image shape: (1328, 1264)
# Coordinate Reference System (CRS): EPSG:3031
# NoData value: 0.0
# GeoTransform (affine transform): | 6268.76, 0.00,-3961855.08|
# | 0.00,-6268.76, 4363055.60|
# | 0.00, 0.00, 1.00|
# Grid resolution (x, y): (6268.7580423772415, 6268.7580423772415)

# %%
# import matplotlib
# matplotlib.use("TkAgg")
#
# import rasterio
# import matplotlib.pyplot as plt
# import cartopy.crs as ccrs
# from rasterio.plot import plotting_extent
#
# with rasterio.open(filepath) as src:
#     data = src.read(1, masked=True)
#     extent = plotting_extent(src)
#     crs = src.crs
#
# # EPSG:3031 = Antarctic Polar Stereographic
# proj = ccrs.SouthPolarStereo()
#
# fig = plt.figure(figsize=(8, 8))
# ax = plt.axes(projection=proj)
#
# data = np.ma.masked_greater(data, 101)
#
# img = ax.imshow(
#     data,
#     extent=extent,
#     transform=proj,
#     cmap="viridis",
#     origin="upper",
#     vmin= 0,
#     vmax =100)
#
# cbar = plt.colorbar(img, ax=ax, shrink = 0.75)
# cbar.set_label('SIC %')
# ax.coastlines(linewidth=0.6)
# ax.set_title(f"Antarctic Polar Stereographic (EPSG:3031)\n {day}")
#
# def format_coord(x, y):
#     lon, lat = ccrs.PlateCarree().transform_point(x, y, proj)
#     return f"Lon: {lon:.3f}°, Lat: {lat:.3f}°"
#
# ax.format_coord = format_coord
#
# import numpy as np
# lon_ticks = np.arange(-180, 181, 30)
# lat_ticks = np.arange(-90, -59, 5)
#
# gl = ax.gridlines(
#     crs=ccrs.PlateCarree(),
#     draw_labels=True,
#     linewidth=0.5,
#     color='gray',
#     alpha=0.7,
#     linestyle='--',
#     xlocs=lon_ticks,
#     ylocs=lat_ticks
# )
# gl.top_labels = False
# gl.right_labels = False
# gl.bottom_labels = True
# gl.left_labels = True
# gl.xlabel_style = {'size': 10}
# gl.ylabel_style = {'size': 10}
#
#
# # Plot a cross at CIS location
# ax.plot(
#     cook_lon,
#     cook_lat,
#     marker='x',            # or 'x'
#     color='red',
#     markersize=5,
#     markeredgewidth=2,
#     transform=ccrs.PlateCarree(),
#     zorder=5
# )
#
# plt.show()

# %%
import matplotlib
matplotlib.use("TkAgg")

import rasterio
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from rasterio.plot import plotting_extent

with rasterio.open(filepath2) as src:
    data = src.read(1, masked=True)
    extent = plotting_extent(src)
    crs = src.crs

# EPSG:3031 = Antarctic Polar Stereographic
proj = ccrs.SouthPolarStereo()

fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=proj)

data = np.ma.masked_greater(data, 101)

img = ax.imshow(
    data,
    extent=extent,
    transform=proj,
    cmap="viridis",
    origin="upper",
    vmin= 0,
    vmax =100)

cbar = plt.colorbar(img, ax=ax, shrink = 0.75)
cbar.set_label('SIC %')
ax.coastlines(linewidth=0.6)
ax.set_title(f"Antarctic Polar Stereographic (EPSG:3031)\n {day2}")

def format_coord(x, y):
    lon, lat = ccrs.PlateCarree().transform_point(x, y, proj)
    return f"Lon: {lon:.3f}°, Lat: {lat:.3f}°"

ax.format_coord = format_coord

import numpy as np
lon_ticks = np.arange(-180, 181, 30)
lat_ticks = np.arange(-90, -59, 5)

gl = ax.gridlines(
    crs=ccrs.PlateCarree(),
    draw_labels=True,
    linewidth=0.5,
    color='gray',
    alpha=0.7,
    linestyle='--',
    xlocs=lon_ticks,
    ylocs=lat_ticks
)
gl.top_labels = False
gl.right_labels = False
gl.bottom_labels = True
gl.left_labels = True
gl.xlabel_style = {'size': 10}
gl.ylabel_style = {'size': 10}

# Plot a cross at CIS location
ax.plot(
    cook_lon,
    cook_lat,
    marker='x',            # or 'x'
    color='red',
    markersize=5,
    markeredgewidth=2,
    transform=ccrs.PlateCarree(),
    zorder=5
)
# ax.text(
#     cook_lon , cook_lat,
#     color='red',
#     fontsize=10,
#     transform=ccrs.PlateCarree(),
#     zorder=5
# )

plt.show()

# %%
# days = ['20260131']
days = ['20260215']

# %%
"""
this loops through the dates i put into days array
"""


import matplotlib
matplotlib.use("Agg")

import rasterio
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from rasterio.plot import plotting_extent
import numpy as np

# List of days you want to loop through
# days = ['20260105', '20260106', '20260107', '20260109', '20260111', '20260114', '20260115','20260116', '20260118' ,'20260119', '20260120']


# Location of your "CIS" cross
cook_lon, cook_lat = 151.4, -69.1

# Base folder path
base_path = '/Users/iw2g24/PycharmProjects/COOKIES/Data/sea_ice/polarview/27_AMSR2'

# Loop over each day
for day in days:
    filepath = f'{base_path}/{day}/{day}.antarctic.tif'

    # Open the raster
    with rasterio.open(filepath) as src:
        data = src.read(1, masked=True)
        extent = plotting_extent(src)
        crs = src.crs

    # Mask values greater than 100
    data = np.ma.masked_greater(data, 101)

    # EPSG:3031 = Antarctic Polar Stereographic
    proj = ccrs.SouthPolarStereo()

    # Create the figure
    fig = plt.figure(figsize=(8, 8))
    ax = plt.axes(projection=proj)

    # Plot the data
    img = ax.imshow(
        data,
        extent=extent,
        transform=proj,
        cmap="viridis",
        origin="upper",
        vmin=0,
        vmax=100
    )

    # Colorbar
    cbar = plt.colorbar(img, ax=ax, shrink=0.75)
    cbar.set_label('SIC %')

    # Coastlines and title
    ax.coastlines(linewidth=0.6)
    ax.set_title(f"Antarctic Polar Stereographic (EPSG:3031)\n{day}")

    # Format coordinates
    def format_coord(x, y):
        lon, lat = ccrs.PlateCarree().transform_point(x, y, proj)
        return f"Lon: {lon:.3f}°, Lat: {lat:.3f}°"

    ax.format_coord = format_coord

    # Gridlines
    lon_ticks = np.arange(-180, 181, 30)
    lat_ticks = np.arange(-90, -59, 5)
    gl = ax.gridlines(
        crs=ccrs.PlateCarree(),
        draw_labels=True,
        linewidth=0.5,
        color='gray',
        alpha=0.7,
        linestyle='--',
        xlocs=lon_ticks,
        ylocs=lat_ticks
    )
    gl.top_labels = False
    gl.right_labels = False
    gl.bottom_labels = True
    gl.left_labels = True
    gl.xlabel_style = {'size': 10}
    gl.ylabel_style = {'size': 10}

    # Plot the CIS cross
    ax.plot(
        cook_lon,
        cook_lat,
        marker='x',
        color='red',
        markersize=5,
        markeredgewidth=2,
        transform=ccrs.PlateCarree(),
        zorder=5
    )

    savedir = '/Users/iw2g24/PycharmProjects/COOKIES/Data/sea_ice/Figures/'
    # Show the plot
    plt.savefig(f'{savedir}{day}_full.png', dpi=300 )
    plt.close(fig)

# %%
# -------------------------
# ZOOMED-IN FIGURE
# -------------------------

days = ['20260215']

"""
this loops through the dates i put into days array
"""


import matplotlib
matplotlib.use("Agg")

import rasterio
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from rasterio.plot import plotting_extent
import numpy as np

# List of days you want to loop through
# days = ['20260105', '20260106', '20260107', '20260109', '20260111', '20260114', '20260115','20260116', '20260118' ,'20260119', '20260120', '20260121']
# days = ['20260128']
# Location of your "CIS" cross
cook_lon, cook_lat = 151.4, -69.1
jan_lon, jan_lat = 141.961247, -65.5113566

# Base folder path
base_path = '/Users/iw2g24/PycharmProjects/COOKIES/Data/sea_ice/polarview/27_AMSR2'

# Loop over each day
for day in days:
    filepath = f'{base_path}/{day}/{day}.antarctic.tif'

    # Open the raster
    with rasterio.open(filepath) as src:
        data = src.read(1, masked=True)
        extent = plotting_extent(src)
        crs = src.crs

    # Mask values greater than 100
    data = np.ma.masked_greater(data, 101)

    # EPSG:3031 = Antarctic Polar Stereographic
    proj = ccrs.SouthPolarStereo()

    fig2 = plt.figure(figsize=(8, 8))
    ax2 = plt.axes(projection=proj)

    zoom_extent = [
        107.63,   # lon_min
        178.705,  # lon_max
        -83.00,   # lat_min
        -63   # lat_max
    ]

    # Set zoom extent (lon/lat!)
    ax2.set_extent(zoom_extent, crs=ccrs.PlateCarree())
    # Format coordinates
    def format_coord(x, y):
        lon, lat = ccrs.PlateCarree().transform_point(x, y, proj)
        return f"Lon: {lon:.3f}°, Lat: {lat:.3f}°"

    ax2.format_coord = format_coord

    img2 = ax2.imshow(
        data,
        extent=extent,
        transform=proj,
        cmap="viridis",
        origin="upper",
        vmin=0,
        vmax=100
    )

    # Colorbar
    cbar2 = plt.colorbar(img2, ax=ax2, shrink=0.75)
    cbar2.set_label('SIC %')

    # Coastlines and title
    ax2.coastlines(linewidth=0.6)
    ax2.set_title(f"Antarctic SIC (Zoomed)\n{day}")

    # Gridlines
    gl2 = ax2.gridlines(
        crs=ccrs.PlateCarree(),
        draw_labels=True,
        linewidth=0.5,
        color='gray',
        alpha=0.7,
        linestyle='--'
    )
    gl2.top_labels = False
    gl2.right_labels = False

    # Plot the CIS cross
    ax2.plot(
        cook_lon,
        cook_lat,
        marker='x',
        color='red',
        markersize=5,
        markeredgewidth=2,
        transform=ccrs.PlateCarree(),
        zorder=5
    )

    # ax2.plot(
    #     jan_lon,
    #     jan_lat,
    #     marker='x',
    #     color='blue',
    #     markersize=5,
    #     markeredgewidth=1,
    #     transform=ccrs.PlateCarree(),
    #     zorder=6
    # )

    # Save zoomed figure
    # savedir = '/Users/iw2g24/PycharmProjects/COOKIES/Data/sea_ice/Figures/'
    # plt.savefig(f'{savedir}{day}_zoom2.png', dpi=300)
    # plt.show()

    savedir = '/Users/iw2g24/PycharmProjects/COOKIES/Data/sea_ice/Figures/'
    plt.savefig(f'{savedir}{day}_zoom.png', dpi=300)     # seconds
    plt.close(fig2)

# %%
"""
this script makes a movie out of the directory of png files for SIC from PolarView
"""

import cv2
import os

fig_type = 'zoom' #'zoom', 'full'
start_date = '20260105'
end_date = '20260215'


fig_dir = '/Users/iw2g24/PycharmProjects/COOKIES/Data/sea_ice/Figures/'
mov_name = f'{fig_type}_{start_date}_{end_date}.mp4'
save_path = fig_dir + mov_name

pre_imgs = os.listdir(fig_dir)
pre_imgs.sort()
img = []

# print(pre_imgs)

for f in pre_imgs:
    if fig_type in f:
        i = fig_dir +f
        img.append(i)

# print(img)

cv2_fourcc = cv2.VideoWriter_fourcc(*'mp4v')
frame = cv2.imread(img[0])
size = list(frame.shape)
del size[2]
# print(size)

video = cv2.VideoWriter(save_path, cv2_fourcc, 10, size)

for i in range(len(img)):
  video.write(cv2.imread(img[i]))
  print('frame', i+1, 'of', len(img))


video.release()
print('video saved to: ', save_path)
# Out:
# frame 1 of 61
# frame 2 of 61
# frame 3 of 61
# frame 4 of 61
# frame 5 of 61
# frame 6 of 61
# frame 7 of 61
# frame 8 of 61
# frame 9 of 61
# frame 10 of 61
# frame 11 of 61
# frame 12 of 61
# frame 13 of 61
# frame 14 of 61
# frame 15 of 61
# frame 16 of 61
# frame 17 of 61
# frame 18 of 61
# frame 19 of 61
# frame 20 of 61
# frame 21 of 61
# frame 22 of 61
# frame 23 of 61
# frame 24 of 61
# frame 25 of 61
# frame 26 of 61
# frame 27 of 61
# frame 28 of 61
# frame 29 of 61
# frame 30 of 61
# frame 31 of 61
# frame 32 of 61
# frame 33 of 61
# frame 34 of 61
# frame 35 of 61
# frame 36 of 61
# frame 37 of 61
# frame 38 of 61
# frame 39 of 61
# frame 40 of 61
# frame 41 of 61
# frame 42 of 61
# frame 43 of 61
# frame 44 of 61
# frame 45 of 61
# frame 46 of 61
# frame 47 of 61
# frame 48 of 61
# frame 49 of 61
# frame 50 of 61
# frame 51 of 61
# frame 52 of 61
# frame 53 of 61
# frame 54 of 61
# frame 55 of 61
# frame 56 of 61
# frame 57 of 61
# frame 58 of 61
# frame 59 of 61
# frame 60 of 61
# frame 61 of 61
# video saved to:  /Users/iw2g24/PycharmProjects/COOKIES/Data/sea_ice/Figures/zoom_20260105_20260215.mp4
# [ WARN:0@86923.077] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.077] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.078] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.078] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.078] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.078] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.079] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.079] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.079] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.079] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.079] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.079] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.079] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.079] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.080] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.080] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.080] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.080] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.080] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.080] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.080] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.080] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.081] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.081] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.081] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.081] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.081] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.081] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.081] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.081] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.082] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.082] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.082] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.082] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.082] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.082] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.082] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.082] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.083] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.083] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.083] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.083] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.083] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.083] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.083] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.083] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.084] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.084] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.084] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.084] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
# [ WARN:0@86923.084] global cap_ffmpeg_impl.hpp:2774 writeFrame write frame skipped - expected 3 channels but got 1
# [ WARN:0@86923.084] global cap_ffmpeg.cpp:218 write FFmpeg: Failed to write frame
